# %%
from bs4 import BeautifulSoup
from haystack.telemetry import tutorial_running
import logging
import os
import pandas as pd
from tabulate import tabulate
from haystack import Pipeline, Document

# %%
tutorial_running(27)

# %%
BASE_DIR = os.path.dirname(os.getcwd())
DATA_DIR = os.path.join(BASE_DIR, "Data")
EXCEL_FILE = os.path.join(DATA_DIR, "query_responses.xlsx")
FEEDBACK_FILE = os.path.join(DATA_DIR, "feedback_dataset.json")
PROMPT_VISUALISATION_FILE = os.path.join(DATA_DIR, "prompt_visualisation.txt")
PROCESSED_CONTENT_FILE = os.path.join(DATA_DIR, "processed_content.txt")
UPLOADED_FILE = os.path.join(DATA_DIR, "uploaded_document.txt")

# %%
def _list_htm_files():
    """
    Recursively finds all .htm files in the DATA_DIR and its subdirectories.
        
    Returns:
        list: A list of full file paths.
    """
    htm_files = []
    for root, _, files in os.walk(DATA_DIR):
        for file in files:
            if file.endswith(".htm"):
                full_path = os.path.join(root, file)  # Get the absolute path
                htm_files.append(full_path)  

    return htm_files

# %%
def extract_text(soup):
    # Extract only meaningful paragraph text
    paragraphs = [p.get_text(strip=True) for p in soup.find_all("p") if len(p.get_text(strip=True)) > 20]  # Exclude very short text
    clean_text = "\n\n".join(paragraphs)
    
    return clean_text

# %%
def extract_table(soup):
    tables = soup.find_all("table")
    
    formatted_tables = []
                    
    # Process and format each table
    for i, table in enumerate(tables, start=1):
        rows = []
        for row in table.find_all("tr"):
            cols = [col.get_text(strip=True) for col in row.find_all(["td", "th"])]
            rows.append(cols)
            
        # Flatten row values for filtering irrelevant tables
        flat_rows = [item.lower().strip() for sublist in rows for item in sublist]
        
        # Skip navigation tables containing only "Back" and "Forward"
        if set(flat_rows).issubset({"back", "forward", "", "-", "next", "previous"}):
            continue  # Skip this table

        # Convert to DataFrame for better readability
        df = pd.DataFrame(rows)
                        
        formatted_table = tabulate(df, headers="firstrow", tablefmt="grid")
        
        formatted_tables.append(formatted_table)
        
    formatted_tables = "\n\n".join(formatted_tables)
    
    return formatted_tables

# %%
def extract_list(soup):
    # Extract lists properly
    lists = []
    for ul in soup.find_all("ul"):
        items = [li.get_text(strip=True) for li in ul.find_all("li")]
        lists.append(items)
    return lists

# %%
def _load_content(selectedOptions=None):
    """
    Load and process all .htm files from the base directory.
    """
    htm_files = _list_htm_files()
    logging.info(f"Found {len(htm_files)} .htm files.")
        
    if selectedOptions is None:
        selectedOptions = ["text", "table", "list"]
        
    # initialise empty training web documents.
    web_documents = []
        
    page_texts = []

    for file_path in htm_files:
        try:
            with open(file_path, encoding="utf-8") as file:
                content = file.read()
                    
                # ignore the redundant header section from content
                content = content[content.find("<body>")+6:content.find("</body>")]
                    
                soup = BeautifulSoup(content, "html.parser")
                    
                page_links = [a['href'] for a in soup.find_all('a', href=True)]
                                                
                
                clean_text = extract_text(soup)
                    
                formatted_table = extract_table(soup)
                    
                lists = extract_list(soup)
                        
                page_text = f"""Tables:\n---\n{formatted_table}\n---\nText:\n---\n{clean_text}\n---\nList:\n---\n{lists}\n---"""
 
                page_texts.append(page_text)
                    
                page_data = {
                    'text': page_text,
                    'link': page_links
                }
                    
                document = Document(
                    content = page_data['text']
                )

                if file_path.endswith("GEO_Limits.htm"):
                    print(f"Content:\n{document.content}")
                    
                web_documents.append(document)
                
        except UnicodeDecodeError:
            logging.error(f"Could not read the file {file_path}. Check the file encoding.")

    return web_documents

# %%
_load_content()
# Out:
# Content:
# Tables:
# ---
# +-----+----------------------------------------------------------------+-----------+
# |   0 | Types                                                          | Limits    |
# +=====+================================================================+===========+
# |   1 | Curves                                                         |           |
# +-----+----------------------------------------------------------------+-----------+
# |   2 | Number of curves                                               | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |   3 | Size of curve units                                            | 24        |
# +-----+----------------------------------------------------------------+-----------+
# |   4 | Size of curve name                                             | 90        |
# +-----+----------------------------------------------------------------+-----------+
# |   5 | Number of data files to form one curve                         | None      |
# +-----+----------------------------------------------------------------+-----------+
# |   6 | Number of pen definitions                                      | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |   7 | Curve selection name                                           | 60        |
# +-----+----------------------------------------------------------------+-----------+
# |   8 | Curve to lithology name                                        | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |   9 | Curve to lithology lithology types                             | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  10 | Data points per curve                                          | Unlimited |
# +-----+----------------------------------------------------------------+-----------+
# |  11 | Computed curve parameters                                      | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  12 | Size of computed curve parameters name                         | 12        |
# +-----+----------------------------------------------------------------+-----------+
# |  13 | Computed curve expressions                                     | 300       |
# +-----+----------------------------------------------------------------+-----------+
# |  14 | Size of computed curve expressions name                        | 25        |
# +-----+----------------------------------------------------------------+-----------+
# |  15 | Size of computed curve parameter description                   | 150       |
# +-----+----------------------------------------------------------------+-----------+
# |  16 | Number of 'curves for surfaces' definitions                    | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  17 | Number of curve synonym-pairs                                  | 500       |
# +-----+----------------------------------------------------------------+-----------+
# |  18 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  19 | Tracks                                                         |           |
# +-----+----------------------------------------------------------------+-----------+
# |  20 | Number of tracks                                               | 200       |
# +-----+----------------------------------------------------------------+-----------+
# |  21 | Number of qualitative tracks                                   | 30        |
# +-----+----------------------------------------------------------------+-----------+
# |  22 | Size of track name                                             | 75        |
# +-----+----------------------------------------------------------------+-----------+
# |  23 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  24 | Curve Shading                                                  |           |
# +-----+----------------------------------------------------------------+-----------+
# |  25 | Number of curve shades per plot                                | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  26 | Number of zones per curve shade                                | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  27 | Curve shade name length                                        | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  28 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  29 | Data Files                                                     |           |
# +-----+----------------------------------------------------------------+-----------+
# |  30 | Number of data files                                           | Unlimited |
# +-----+----------------------------------------------------------------+-----------+
# |  31 | Columns per data file                                          | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |  32 | Size of file name (including the path names)                   | 255       |
# +-----+----------------------------------------------------------------+-----------+
# |  33 | Size of file ID                                                | 9         |
# +-----+----------------------------------------------------------------+-----------+
# |  34 | Number of file ID                                              | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  35 | Auto file load definition name                                 | 40        |
# +-----+----------------------------------------------------------------+-----------+
# |  36 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  37 | Mnemonics                                                      |           |
# +-----+----------------------------------------------------------------+-----------+
# |  38 | Number of mnemonics per file                                   | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  39 | Number of mnemonics per plot                                   | 600       |
# +-----+----------------------------------------------------------------+-----------+
# |  40 | Size of curve mnemonic                                         | 32        |
# +-----+----------------------------------------------------------------+-----------+
# |  41 | Size of file mnemonic value                                    | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  42 | Size of plot mnemonic value                                    | 1000      |
# +-----+----------------------------------------------------------------+-----------+
# |  43 | Size of mnemonic description                                   | 40        |
# +-----+----------------------------------------------------------------+-----------+
# |  44 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  45 | Free Format Text                                               |           |
# +-----+----------------------------------------------------------------+-----------+
# |  46 | Number of free format text blocks per plot                     | 4500      |
# +-----+----------------------------------------------------------------+-----------+
# |  47 | Number of characters per free format text block                | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  48 | Number of free format text's related to a symbol               | 6         |
# +-----+----------------------------------------------------------------+-----------+
# |  49 | Number of free format text tags                                | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  50 | Free format text tag size                                      | 31        |
# +-----+----------------------------------------------------------------+-----------+
# |  51 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  52 | Track Text                                                     |           |
# +-----+----------------------------------------------------------------+-----------+
# |  53 | Number of track text blocks per plot                           | 6000      |
# +-----+----------------------------------------------------------------+-----------+
# |  54 | Number of characters per track text block                      | 32000     |
# +-----+----------------------------------------------------------------+-----------+
# |  55 | Number of qualitative tracks                                   | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  56 | Number of graduations per qualitative track                    | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  57 | Qualitative track name length                                  | 32        |
# +-----+----------------------------------------------------------------+-----------+
# |  58 | Qualitative track abbreviation length                          | 8         |
# +-----+----------------------------------------------------------------+-----------+
# |  59 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  60 | Tables                                                         |           |
# +-----+----------------------------------------------------------------+-----------+
# |  61 | Number of tables                                               | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  62 | Number of rows in 'operations diary' type table                | 4320      |
# +-----+----------------------------------------------------------------+-----------+
# |  63 | Number of rows in 'normal' and 'operations remarks' type table | 32000     |
# +-----+----------------------------------------------------------------+-----------+
# |  64 | Number of fields in a row`                                     | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  65 | Columns per table                                              | 4320      |
# +-----+----------------------------------------------------------------+-----------+
# |  66 | Size of table name                                             | 29        |
# +-----+----------------------------------------------------------------+-----------+
# |  67 | Size of table ID                                               | 12        |
# +-----+----------------------------------------------------------------+-----------+
# |  68 | Size of table column heading                                   | 29        |
# +-----+----------------------------------------------------------------+-----------+
# |  69 | Size of postfix                                                | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  70 | Characters for all columns in table                            | 10000     |
# +-----+----------------------------------------------------------------+-----------+
# |  71 | Characters for an individual cell                              | 1999      |
# +-----+----------------------------------------------------------------+-----------+
# |  72 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  73 | Lithology (includes Structures)                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  74 | Number of lithology types                                      | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |  75 | Number of lithology sections per plot                          | 20000     |
# +-----+----------------------------------------------------------------+-----------+
# |  76 | %Litho track per plot                                          | 3         |
# +-----+----------------------------------------------------------------+-----------+
# |  77 | Number of lithology types per %Litho track                     | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  78 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  79 | Modifiers                                                      |           |
# +-----+----------------------------------------------------------------+-----------+
# |  80 | Number of modifier types                                       | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |  81 | Number of modifiers per plot                                   | 20000     |
# +-----+----------------------------------------------------------------+-----------+
# |  82 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  83 | Symbols                                                        |           |
# +-----+----------------------------------------------------------------+-----------+
# |  84 | Number of symbol types                                         | 1000      |
# +-----+----------------------------------------------------------------+-----------+
# |  85 | Number of symbols per plot                                     | 10000     |
# +-----+----------------------------------------------------------------+-----------+
# |  86 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  87 | Lines                                                          |           |
# +-----+----------------------------------------------------------------+-----------+
# |  88 | Number of lines per plot                                       | 750       |
# +-----+----------------------------------------------------------------+-----------+
# |  89 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  90 | Headers and Trailers                                           |           |
# +-----+----------------------------------------------------------------+-----------+
# |  91 | Number of header & trailers specification files                | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  92 | Number of specifications to make a plot header                 | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  93 | Number of specifications to make a plot trailer                | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  94 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  95 | Tadpole                                                        |           |
# +-----+----------------------------------------------------------------+-----------+
# |  96 | Tadpole definitions                                            | 5         |
# +-----+----------------------------------------------------------------+-----------+
# |  97 | Tadpole definitions name                                       | 16        |
# +-----+----------------------------------------------------------------+-----------+
# |  98 | Minimum dip value                                              | 0         |
# +-----+----------------------------------------------------------------+-----------+
# |  99 | Maximum dip value                                              | 90        |
# +-----+----------------------------------------------------------------+-----------+
# | 100 | Minimum azimuth value                                          | 0         |
# +-----+----------------------------------------------------------------+-----------+
# | 101 | Maximum azimuth value                                          | 360       |
# +-----+----------------------------------------------------------------+-----------+
# | 102 | Maximum dip types                                              | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 103 | Maximum length of dip type name                                | 63        |
# +-----+----------------------------------------------------------------+-----------+
# | 104 | Maximum tadpole definition templates                           | 50        |
# +-----+----------------------------------------------------------------+-----------+
# | 105 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 106 | System/General                                                 |           |
# +-----+----------------------------------------------------------------+-----------+
# | 107 | Minimum zoom                                                   | 0.1       |
# +-----+----------------------------------------------------------------+-----------+
# | 108 | Maximum zoom                                                   | 10        |
# +-----+----------------------------------------------------------------+-----------+
# | 109 | Size of plot description                                       | 29        |
# +-----+----------------------------------------------------------------+-----------+
# | 110 | Number of CGM fonts for font mapping                           | 20        |
# +-----+----------------------------------------------------------------+-----------+
# | 111 | Size of CGM font name                                          | 30        |
# +-----+----------------------------------------------------------------+-----------+
# | 112 | Scale settings                                                 | 23        |
# +-----+----------------------------------------------------------------+-----------+
# | 113 | Password length                                                | 16        |
# +-----+----------------------------------------------------------------+-----------+
# | 114 | Size of image name                                             | 32        |
# +-----+----------------------------------------------------------------+-----------+
# | 115 | User ID's per plot                                             | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 116 | Vendor ID's per plot                                           | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 117 | Maximum layouts per ODF                                        | 19        |
# +-----+----------------------------------------------------------------+-----------+
# | 118 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 119 | VectDraw or Vector Object                                      |           |
# +-----+----------------------------------------------------------------+-----------+
# | 120 | Number of points per polygon in VOB                            | 20        |
# +-----+----------------------------------------------------------------+-----------+
# | 121 | Number of different fonts for VOB                              | 50        |
# +-----+----------------------------------------------------------------+-----------+
# | 122 | Size of text in VOB                                            | 300       |
# +-----+----------------------------------------------------------------+-----------+
# | 123 | Memory for all bitmaps and VOBs                                | 300 KB    |
# +-----+----------------------------------------------------------------+-----------+
# | 124 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 125 | Imaging Tools                                                  |           |
# +-----+----------------------------------------------------------------+-----------+
# | 126 | Maximum imaging tools                                          | 10        |
# +-----+----------------------------------------------------------------+-----------+
# | 127 | Maximum pads per tool                                          | 10        |
# +-----+----------------------------------------------------------------+-----------+
# | 128 | Maximum sensors per pad                                        | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 129 | Maximum name length                                            | 63        |
# +-----+----------------------------------------------------------------+-----------+
# | 130 | Maximum significant decimals                                   | 4         |
# +-----+----------------------------------------------------------------+-----------+
# | 131 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 132 | Zones                                                          |           |
# +-----+----------------------------------------------------------------+-----------+
# | 133 | Number of query definitions per zone type                      | 75        |
# +-----+----------------------------------------------------------------+-----------+
# | 134 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 135 | Correlation                                                    |           |
# +-----+----------------------------------------------------------------+-----------+
# | 136 | Correlation items                                              | 50        |
# +-----+----------------------------------------------------------------+-----------+
# ---
# Text:
# ---
# *Maximize screen to view table of contents*
#
# The following restrictions currently apply within each session of GEO, or instance ofODFfile.
#
# Once a limit is reached, the system may beep and/or display an error message for that object type.
#
# To check whether the following limits have been exceeded, click Statistics from the Help menu.
#
# The Statistics dialog box displays the number of modifiers, lithologies, symbols, texts and lines, which are being used in the currently-open ODF.
# ---
# List:
# ---
# []
# ---
# [Document(id=7c3d1fb644e578c4b30e1307d41c0f9f96185eb9183dcecae1dc19f0cb6df8b0, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  We have support centers stra...'),
#  Document(id=952795e8097983e0f9a8391f1f0313122a4c6ebcc3838d66bb755def78baf0c3, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#
#  ---
#  List:
#  ---
#  []
#  ---'),
#  Document(id=d562eb8f38d0288d09a8e821aba52c189cd325031e9072c866d3e88834f44734, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  In this help system you will...'),
#  Document(id=6fa148850b0946198889bc10bdfa908eb7609d26aaf644cd98ff0ba609aebb3a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  The help content for this dialog box is currently not available. In the m...'),
#  Document(id=a456e6ae1073b08d3eaa1323897729edf0fdb04dcfdca0cdf1c44fba3b9f2722, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#
#  ---
#  List:
#  ---
#  [['', '', ''], [''], [], ['', ''], [''], []]
#  ---'),
#  Document(id=3a4889757fcf12dddb5871901833975e3fa5300a559eb58d0a1050bea08979de, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#
#  ---
#  List:
#  ---
#  [['', '', ''], [], ['', '', ''], [''], [], ['', ''], [''],...'),
#  Document(id=50b96e90c0207c12a41f29a71b516d87d70f3ea734bcfd75ee76d2aa131203ad, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Cement volume calculation
#  --...'),
#  Document(id=cf742bf1d5e475a0a038b856124253f458339bdd233b3397b5d37317dc90b710, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  DescriptionD-Exponent Calcul...'),
#  Document(id=0a117a70a08bba3dcc0efcd820b1798b67f9bcab1b08e7296abdcaf99dbe20b9, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Mechanical Specific Energy
#
#  ...'),
#  Document(id=338b0780b1814d2c7739c18b4ec99d8a1497efecb943af572ebc10b306bd4f94, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Calculating in Formation Tem...'),
#  Document(id=688ff09814b7e61cefa9d9c6a6ed809e3d8de147635e4e422a6572b2dced336c, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  C1 divided by the sum of chr...'),
#  Document(id=ac6534a6cdf23db936047ed8767f1e897e9eddab43bbf57bc091b956eb939cfd, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Gas Balance Calculation
#
#  GBH...'),
#  Document(id=635f47195b1892790995c8dfd96217db54aafe91ed2023105084ad8866fb5f05, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Gas Character Calculation
#
#  G...'),
#  Document(id=4240eb00b6307f5a88d1e5c09367fcbde3b1db4194d30b567c8ccde923f25fcf, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Gas Wetness Calculation
#
#  GWH...'),
#  Document(id=07cf27e1f7b406eb5a0fea4a482ebe6cb2469e33e25757332aa406db74f0c606, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Inverse Oil Indicator
#
#  Inver...'),
#  Document(id=cf1395f85b272df9187b9f2d534015ffba8db6478fb3428dcce5fa1e20e15338, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Oil indicator to be used in ...'),
#  Document(id=f3a65bed18a7efc036f8204322926f093e0dbf34feca6e83379b74efd9bfcefd, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Pixler C1/C2 Gas Ratio
#
#  C1/C...'),
#  Document(id=0252541839b6630dd08e2676963f2127a2156cd1041c3bf679527414578199d4, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Pixler C1/C3 Gas Ratio
#
#  C1/C...'),
#  Document(id=a0eedd0a5d931f8739e3a7a6a15ae62bf8efe67bfc887a178560bea09efd095d, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Pixler C1/C4 Gas Ratio
#
#  C1/C...'),
#  Document(id=6cd0ebcf51fb6de178e64f66bb8c86a3ecafb4a1d0f439fc36f8401645d742b9, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Pixler C1/C5 Gas Ratio
#
#  C1/C...'),
#  Document(id=b34dc094d2bfb0ab887eabd6b4963b1fcf43401cdb7678c4e6fcd376280795ab, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  5 fold moving average of C1 ...'),
#  Document(id=7b0d78393e77bed76413dbf4a6ab6a6f611007d80072e834a479bca190a19723, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Description5 fold moving ave...'),
#  Document(id=f229ace31131bc1368d11b9ebdcb7d29280ef83cf26771a4008f507474fa5ae8, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Delta C1 Moving Average
#
#  Use...'),
#  Document(id=ac79404fd98eb67c5e3a0871d37313ef589bd4bc17e9b2ab822c541127ba15cc, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Delta C2 Moving Average
#
#  Use...'),
#  Document(id=84b6b5ce776fc1b143fb29a931c89b7028f60661820c4e563736f30d957e70c2, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Delta Total Gas Moving Avera...'),
#  Document(id=3cdf99eaf7d7078e6af7432ae709b5e4509bdb67e4f1b7c31575845afef00e70, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Compares the Total Gas value...'),
#  Document(id=77a5a65c4bfca61ca153163c9f9c3a9fc1d03825aadfdc6db5585b35a354e7e9, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Used to convert the Total Ga...'),
#  Document(id=6148e0fab8530e51e106404205ab8c458d25a4606b2bd0f0db0a172e9063a091, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Total Gas Moving Average
#
#  5 ...'),
#  Document(id=749954821c6b375dd7a711c27abfe9508d4d0d97c4f01be388e9030bb1dddac1, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Total Gas Normalization
#
#  Nor...'),
#  Document(id=b12eb785aec434498f27cbd9beb03655736b870163da08db074e83bbcbf36da5, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using ARCHIE. Rw...'),
#  Document(id=648efcec897985daef327db6294ced4651bdc9781457751f64683dd297e4de0b, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using ARCHIE. Rw...'),
#  Document(id=5eaba7428a9e469e38cf9ed30f400283f122663fdbb82324a974e3b20e391e21, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using INDONESIAN...'),
#  Document(id=976f6c8442d59cbb9be505017318af1b57133e477c5a41b56e2bdc37cc931d39, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using INDONESIAN...'),
#  Document(id=6b242b770147c649309b759997273e64a9aa8acbe362edbc172c19f2ca6b63ed, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using SCHLUMBERG...'),
#  Document(id=8bc0744c10b79746f9af700989841512aefb46177bd2692fb386c5a176fff2cc, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using SCHLUMBERG...'),
#  Document(id=b3f343cd5ec636d3ae2b88b31ef82a6ea6b1f751174c3d37a67242a77887f242, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using SIMANDOUX....'),
#  Document(id=fd005b2b9bd0e556eb1b23bfafac370f4b8fb9a8d1238d55740b2064f59fea4f, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Net Pay (Sw using SIMANDOUX....'),
#  Document(id=c1e4cc57f24fd040bc7e617cca36396e6aaf1094aa6f5d89cdd7bacaf46602e2, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Porosity Effective (Clean Zo...'),
#  Document(id=b995a9df79a8212a4fb77bc64f68b1c4ec5b75ae795a53f73f2196c5079ad7d6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Porosity Effective (with Sha...'),
#  Document(id=6fc13637973b10f09fb8da90b50e215da7e521448705e5daa3715fa1bf4fb898, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Porosity from Density (Clean...'),
#  Document(id=9656cc6a3aea61c23cf60d3fc26ffce4aab0737da6425d61da6011dc39f6a7e8, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Porosity from Density (with ...'),
#  Document(id=fadf45a19f54fa953330dd6d94848404247dd4adde4f656d5b5f8ab91a81095c, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Porosity from Sonic (Clean Z...'),
#  Document(id=3ebc02b1cb48c42cccc2af6c4e30a8749088aab2e5822f1830df919b4338d174, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Porosity from Sonic (with Sh...'),
#  Document(id=58013df3d7cbb1a59bfd113e484a2bfa9aa8d7d175336191ad185d05c09bf59d, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Rw at Formation Temperature
#  ...'),
#  Document(id=fdb4ede4f93b1ce95ac41d083be2040a7f1ebcaadbb8fdaa310e658f7241c438, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Calculating Rw from SSP read...'),
#  Document(id=13223c8b0d73b0cdec99e489b21669c67576461324eb98af1a1ff8a9c97392fd, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Calculating Shale Volume fro...'),
#  Document(id=f4829cf438bd3cec23382a87b0d30740f5b5f93ee45890f44bc43bddbcaa13aa, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Sw using ARCHIE (Rw known)
#
#  ...'),
#  Document(id=952225a9b8f01fa4c80f382cb2a25623fb135f9b3e76f7b5f3d2fa2b0ec81caf, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Sw using ARCHIE (Rw known)
#
#  ...'),
#  Document(id=5e23ff66a29c88acaf4a1be6126cf2986f630d86acba3f3bd34908dd27256538, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  NameSw using INDONESIAN (Rw ...'),
#  Document(id=5bb9ac69048dabcb9a7b2c0b05eb1a182986faafe84a9f5584fac04968c9946a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Sw using INDONESIAN (Rw know...'),
#  Document(id=61e60d854897881069208c600055469e633a054704df4f83e8943951228b0c95, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Sw using SCHLUMBERGER (Rw kn...'),
#  Document(id=8a733f8bcfcfc30e38151fcc5e4c6c7765f53f780b252be6e38004b472cf6138, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Sw using SCHLUMBERGER (Rw kn...'),
#  Document(id=eb87f1d50e47d74167cf8532ef4e6ebda5dd586c232e55c5b070b2f6b3482002, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Sw using SIMANDOUX (Rw from ...'),
#  Document(id=36d29b7d88f2ad4fed5dec3aac7cac57a5e4ad1236578f2675a4979610de240e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Sw using SIMANDOUX (Rw known...'),
#  Document(id=e02d327ac872796c387fc47a739735d0fb0a3f3c113ea2ff78f56c847a73e0fc, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Thorium to Potassium Ratio, ...'),
#  Document(id=1c0c28969dd7beb090a910ffdbfd4dfbed2773c99ad82a11c09c4c1b4c9135dd, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Calculation of well departur...'),
#  Document(id=0361287d05c605f987e5094a1f8aace474fd851416156d63380257d1b133da04, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Calculation of well departur...'),
#  Document(id=5ad774f0253d194ca5c2e188f492547edfff1f44635c063b62e7fb410817c613, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  TVD using Minimum Curvature ...'),
#  Document(id=50885f5a39481b67f9bdc4e2f8a5b5b7615cf44dc3247084a6cb059d60e4109c, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  TVD using Average Tangential...'),
#  Document(id=9ae83c7b1949f7f9c6d045846428be9615cfbffccfea319619dca731757aeaf5, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Projection of well departure...'),
#  Document(id=aecf5d15828d94d8a241777ac867bb0fb398ee1f36f270aa340cd0f18e7d10cd, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Calculation of the distance ...'),
#  Document(id=450fb2dc7974b2c033da099bd0a672cd64b0c7c5f7694fda1390e684dae64296, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Data typically stored in tab...'),
#  Document(id=00f47257420352319a80814f62421b72cf05453d0ab3d531fb450b27f4054735, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Create a zoned curve - a Cut...'),
#  Document(id=5a74e9d57a2c4bc8ab0e8430484869dbdd4d8b5ab2817fa9921ddb22533b7577, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Manually create more than on...'),
#  Document(id=1720e25792e027b5bf6eeaffb474579d6d60e737878519040718f0ec3c45ea9b, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Create Polyline Curves - use...'),
#  Document(id=69939606111a599fac1660b77545bf7a9ce8de684d0a0f2f57e59822d46e3a69, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  On theCurvestab, selectCurve...'),
#  Document(id=8b4cc750cefe89c45a8e3b89c5086beb60c0aeb12eaa61dc1169d7bb37528186, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  This dialog box allows you t...'),
#  Document(id=11e346ab37295e78cdf03ab255a6e1be65810c3462f0436a2f54b070f223c8ba, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  On theCurvestab, selectCurve...'),
#  Document(id=e363542562d3c8a34dd09bdb39a2c1a4c45e27719fc49dea5fd46e9712a7adc5, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Display integrated travel ti...'),
#  Document(id=54a78bd8bcf28707282c76e8a0587a4f20bc22489d2dcfae095e259120165156, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Use this procedure to flat-l...'),
#  Document(id=f8af3dcc2f8b24fb75fc2c5d8b31dd71f1d9bc045931bab0b4e39bdd50aefde6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents
#
#  Multiple curves can be groupe...'),
#  Document(id=e48a10b60e642e1fe2dbe3494bf05127f74b7c88a3796314ed365189f53ce7eb, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  View the load and amendment ...'),
#  Document(id=33c2eb94038fbcf7df73a4957e94731e24f88ad13947c13fecb17c1cbe7bec28, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  On theDefinetab, selectAutoLoad. The Auto Load Definitions dialog box wil...'),
#  Document(id=b1b4d4c5aef5d1e2f0d2069f58d67d73ebd21dbc1be8d145a561085c12ac5485, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  You can load data files or either comma-separated (CSV) or tab-delimited ...'),
#  Document(id=857d38b8e132f263ba9077d1611050f73462842853a28de2301092dd9f294418, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  1.    On theToolstab, clickLIS to LAS.2.    A message displays detailing ...'),
#  Document(id=68c9b762f926372622a3029058b7ef5c5bfc55a81ce45490a4dc5a54c9fe7a79, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  The data import wizard loads curves into an odf.
#
#  Data Import Wizard Step...'),
#  Document(id=efb5ac21395a10775d397160e42c62c7e5770eb963414578ad25b5e8bfa0e781, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  The process of importing or loading an XML file is very similar to that o...'),
#  Document(id=952795e8097983e0f9a8391f1f0313122a4c6ebcc3838d66bb755def78baf0c3, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#
#  ---
#  List:
#  ---
#  []
#  ---'),
#  Document(id=47d8e7808087eac50e7865b27682ecb5bf4894ab7954c278e21bfaf7693c2d0e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  In a space-delimited ASCII data file, cells in a column are separated fro...'),
#  Document(id=b1b3ad46f2a98c1dec8e0592126365bda4fe7e6072c635ccd01a943d7863b11d, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The order of curve legends o...'),
#  Document(id=c7f498c45d410ddcf6b4e8284c25cb4db0a55646a8f051f46913b2b2c15e21cc, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The display settings for eac...'),
#  Document(id=c1b369ab3ebe0476bd8abd7e6b432581478363909e012d88357bfdfb5d084a3e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  This feature allows you to s...'),
#  Document(id=148fb4481d4aef9c391fba9e11abf9e4512e10833763c09f15fcb626499eac5a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Select the curve on the plot...'),
#  Document(id=b832f66f0027c1bdea83c4755ab42ff5c4dc861ff936590083793d2b3b6a1bad, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Change the pen type and colo...'),
#  Document(id=e815b056bf2af6089e107263ce3cfa09ac0932adc9c086d2baaf7eb6ad85f119, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Plot Azimuthal distribution ...'),
#  Document(id=964094283fed6c997fa363090ea6b1e65a5896af85471cc56d6ad3460ee32466, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  All curves can be displayed ...'),
#  Document(id=d61b80d20d3036cc567eb3b3739d76bb72b9d205e85cb04ac500b1a03ceaa071, content: 'Tables:
#  ---
#  +-----+--------------+------------------------------------------------------------------...'),
#  Document(id=64cdc1bfcb02c63cf373142730b8d930dea7b53ee54adf7e399c4efe590a71ac, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Customize the way pens appea...'),
#  Document(id=9abc802881b3172ed9b0e73a5a5691f5aeec46d837887e470f89ea84a618996e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Data points in a curve can b...'),
#  Document(id=3fdbca1151d8b5309cdcedbf1647bb18ec34f211e04bd3fb4b73201a914c2b95, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Display curve values which a...'),
#  Document(id=b52f5da3de08f9b255c7e9b9c55fbe0a3e2422c385cf480f8de8f6ff3b8d12f9, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Display the curve mnemonic o...'),
#  Document(id=67536d331ef1e113b63bc147bb015b941679a531fc436e20a3d6cbfbc0a61853, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  View and modify tadpole Data...'),
#  Document(id=12f3d8ff11a3c15eb09af48cc211ea0b4921e444039999160011714b8f73b1e6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  You can have multiple scales...'),
#  Document(id=cadf12010428b28fb13bbbeee50cedc12211ca8403a896ebf351fd72b2e853da, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Change the curve name, its m...'),
#  Document(id=dd9cc314b60235716e767d7f7e29ba4d94c09ea97105e3e5b74dc80ca95b9dae, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The Curve Settings sidebar p...'),
#  Document(id=a3e864d6d12c786f9a38de0791f17a16e0811dc465fc355ef2d00e2490ad771e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  A tadpole plot is used to pr...'),
#  Document(id=d71cac3038f74179abe121872d9e49b7288bd68c03842ee1d2e767101025bcef, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The display settings for eac...'),
#  Document(id=191c47e82508a05f5413406bdf0b0906046deb8701517c70647da61cb901f1e7, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Shade the region between two...'),
#  Document(id=91cae928c9a232fbf69a10f2a013aff1767ea6b86aac26c96b320e5d577a4832, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Lithologies can be applied a...'),
#  Document(id=cd2619e991f44f41e9ef4c8bafeacdabded3c768a8813b792d66666a5ee62495, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The depth of curves can be s...'),
#  Document(id=a33dda246f868352ffa49b129ac6fbb8836cef5898239468ed5711f2c5c70f35, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Shade between the wrapped (o...'),
#  Document(id=bbffa865904a9cfd0ca479cb293ef6ded137f6e838c833bf4f6ab8a4815a2cab, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Take portions of different c...'),
#  Document(id=d6298bbb47a1b39029035e4d72308bd9ed742258ec00fa4590e827832eafb9a9, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  Shade the region between two curves, between a track edge and a curve or ...'),
#  Document(id=fb155b1f4f150f5c7d3f5ed7d250f5b3ea3131cfdcbd8605bd935dc81428a9ff, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  Lithologies can be applied as curve shading in two ways.
#
#  Lithology shadi...'),
#  Document(id=6c68510ddf4deea34760c1736337e827495a475501c1e03f43eca39ba83f6331, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  Shade between the wrapped (or out-of scale value) curves and the left or ...'),
#  Document(id=a1b79a0a9d1e32f95a86249f9cd710909c20f67c39d5e52ad77ae72e774d5e35, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  Take portions of different curves and splice them together to form a new ...'),
#  Document(id=87e695f2fc834b82af6b58f822cc4de9d0d19e42d50354c713a7bbaed15a337c, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Free Format Text is text whi...'),
#  Document(id=cec44b2bc32a24dfb704fce950f96d76e53501bc176da42eb300b4ba32fcdb3b, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Select the free format text ...'),
#  Document(id=1127dc23c3bad7d9d657ee9d788a9efd242e7bd03b2d12a9032c1fac09be5a6c, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Select the free format text....'),
#  Document(id=c9aae6fc80f890ef131a77150b8ab394db3486e5c67497569d1e382044f7c99b, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Select the text and drag it ...'),
#  Document(id=49b62a197f71ee770eb60ed0384c11b45c7228df8ee3466b5697eb9531cd98ec, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The process of adding a Grap...'),
#  Document(id=f1acd74a9069a5cb9c62b5c9f7dd37e35a683e90fc85c257c6b742826911999a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  GEOGraph is an integrated ap...'),
#  Document(id=9ac12a6c26f1cfda5c8ceab19122c6c1091a63003b1337dd251360a0bb4d032f, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The header is all well infor...'),
#  Document(id=6bb00abbf34cdb509535276ff90e6954aee170c7225d0a8711fb3bcea55f7292, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The header is the top sectio...'),
#  Document(id=186a95fcbb0fc971a069943b9ff8ca7f7f613d90f6311e8211d07c29cd21960e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Vector Object orVOBfiles may...'),
#  Document(id=a013e86b89d208310da44eb6abef5290c7617dcd2a7c38a443bc4aaef10f6d43, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The header and trailer items...'),
#  Document(id=f1f91fbb2672849f390eace077e9377c2b0613ba2c5efb304dcc43808cd341ae, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  To add headers or trailers t...'),
#  Document(id=aea531ca6f503fe1c0f5ad5cb0efbf669ebbafd6205680550ce7461566d207ea, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The font type, size and styl...'),
#  Document(id=1b5a58ece7bff2036921f1782310d2b1b26bf1730f7e6404f2009f2d189593c9, content: 'Tables:
#  ---
# ...
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Change track text and free f...'),
#  Document(id=01ac3610719a26fb96db6a695a5272c7a045b036f1ec9fd2d26af65c5db74097, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Change the color of track te...'),
#  Document(id=e02cf39f0665d200acf4b6d793f9db2903fbc2d1386a822d1ae4cb59833d4c0e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The track text and free form...'),
#  Document(id=39a278d0594480966a7c09f8428caf33b2d482748b35473553acd609b9d8714e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The track text and free form...'),
#  Document(id=ddaf945660ef1b06519b0c38b695d93a3cd8a4b57ad9c76b2ea050c1ad983829, content: 'Tables:
#  ---
#  +-----+----------+----------------------+-----------------------------------------------...'),
#  Document(id=adb16628f03ce8a62fac38965014069f8b5dc19d6570c69c89eb0eb30934b586, content: 'Tables:
#  ---
#  +-----+----------+----------------------+-----------------------------------------------...'),
#  Document(id=927f2c4535dcd8fd45adfa620ea9f3fe14e04b463a17a682f4654d92777cf32e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Insert a subscript character...'),
#  Document(id=8dd7b46cc4897d1c205fd23bd3749e58c8979a8fcd67193fd5257048d63293a7, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Insert a superscript charact...'),
#  Document(id=bca547121874c8999c8750d39fe8f31bc241fcac8311e94cbcb6a59e87b11e79, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The track text and free form...'),
#  Document(id=fd3bf4f511b24eb17f556a6563b539f5d76b6c28f261c4eb14e8ab6177854768, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The track text and free form...'),
#  Document(id=78af82a85ec75c684311ca8e80c1f7d759a993b36eda74812d9cb19adcb96644, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The track text and free form...'),
#  Document(id=9ef20cf607f91b7abe39d462525328730b1735d9493fd560d34370239ca32579, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Strikethrough track text and...'),
#  Document(id=777232e800b35fc5128be9bc179d6b699e26b4316f5ee158977df22535c28f7d, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The track text and free form...'),
#  Document(id=d56dcc6445abc01b1fcf0bfd7c2782d335aa72a72d79249c2dc2903da1237e6e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Configuring an ODF to be ope...'),
#  Document(id=5a13349dcf43f9ea503914132e897bceed7571466ba27835d3e28a341379eb8a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The Event log records import...'),
#  Document(id=a78cef205eca09eb438cc4020fd882e52d93dc69dde2e85a8167348312ba7c83, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  To jump or go to a certain p...'),
#  Document(id=9d7be28ab3420915ce8688f293e90448442de5e4be913e8bf24fe62f149d863a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  In order to preserve secrecy...'),
#  Document(id=440598781fc528a0ff46e7736a8ed9095df3a0b5c727ab9250095379ea36374a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  ODF files can be password pr...'),
#  Document(id=6fbda7e8638433646d161f52aff7d89edde5179910848ab1ceb0b182408ea712, content: 'Tables:
#  ---
#  +-----+---------------+-----------------------------------------------------------------...'),
#  Document(id=9a1e75d0bcfa78d666a051a93fa6db64c30a29fa4ef1725729af29449fb471c6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  You can provide additional i...'),
#  Document(id=43f11d4ce00abebdebe9a82d189d3d6fbecf6c98d4d0fe5339c418be50ec082e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  You can now export and impor...'),
#  Document(id=1abc19b79c4082d62ff87f3ae7e02b384eca84617931b876087fbfa4d460ea57, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Some of the information used...'),
#  Document(id=6f5f0ed170ccbdf453cfd48ab83dc151866ea6f7c2d452ee976e04e9169f423a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  You can export the complete ...'),
#  Document(id=13e19dd1b92f339b77eefda52cee73030df82da60cdf3842798f2b1d644367fa, content: 'Tables:
#  ---
#  +-----+-------------+-------------------------------------------------------------------...'),
#  Document(id=87c0959ad16bc9a4ab0116521027437ff2747df0572157248e29348c610a7da0, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  XML(eXtensible Markup Langua...'),
#  Document(id=3cdabc731ccb77e3fa042d9153d8d4eff8226186407327ea5a8a9417414fd0c9, content: 'Tables:
#  ---
#  +-----+-------------------+-------------------------------------------------------------...'),
#  Document(id=fd0d8843d9fb1eefb98bf7a7c90774a6d02a98253b68d2bd6b554ea359a52b1f, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  There are multiple options f...'),
#  Document(id=1a39bdb801fbefa4555d4a7f327f4d117eaff3320df2631c244a4346692bde18, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The CGM (Computer Graphic Me...'),
#  Document(id=b949808b6a6922ae996ea1704acfbf01d6e365547ea631023a39012712916df6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  EMF (Enhanced Meta File) may...'),
#  Document(id=82f6ec8e0372f27dd52e505695d8491d1d6dec10b02e1da70ed7317e384bd37a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Scalable Vector Graphics (SV...'),
#  Document(id=e2109c4f163c314e3d609b4b5d642ef167ae1c2aaedb7d8fe0d6ac97c6507734, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The TIFF export option can b...'),
#  Document(id=26bf8206afc08e989b7198736ecc90943dbaf5f9914f65a044d6cd56c1d83332, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  In WindowsÔ, most major appl...'),
#  Document(id=63debd3903888beaa08e97fe6ebaae24810156d8a98f1c093cc623e758413bc6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Exporting to HTML outputs an...'),
#  Document(id=cab0e011e05598e0b12e22b34977f47d58bd341dfa7fdac40a68923c2e891b65, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The ODF Update File or OUF, ...'),
#  Document(id=e0de66647029b3a457ec69d13638e2e71f7d9bb82e7a6b1ff85102d6f3f211c4, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Save an ODF file in the norm...'),
#  Document(id=314e53e7873828b2ca75a357c15972f3bfd865c45a2c465ec37f8529e804e552, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Upon receiving an OUF file, ...'),
#  Document(id=c2659f325786e169e1c4809ec1517589959027b0f9d5fae84ca4df3443ad3487, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The Auto merge OUF feature a...'),
#  Document(id=c22434c65fa57e1e61f34422643e8f65485ca1cf7a50b7782864b03d4559dd33, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  What happens if somehow the ...'),
#  Document(id=f015128d5fa21cad72d40e31efce8ecd170f8d63b044b597c0e311276dcc047e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  In most cases, the OUF will ...'),
#  Document(id=a1e86a57ca97c23bbb82bccd97b64e6d60bf76e1a6dd6a418456c378ec191c17, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  With the VUF feature it is p...'),
#  Document(id=a62dc77d77f907641c1f0e61489c73f0b054c8db5cf36e3e4fb99bbdcc1fdb40, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  A sidetrack well can be crea...'),
#  Document(id=3b47e02b5f11fca11b3108ca9378fec9189efdbaa6aae2697cc6343fe3c931c6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Symbols are used to add impo...'),
#  Document(id=837461c00b6fbdd6d9d3c43da15a0bd995f311216a95e45c99e55b25109e353a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Select the symbol and hitDel...'),
#  Document(id=f62546f44d027ad34da0c48b9089e9f940cdc86d46f6dd16400c3aef7e1a9d01, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Select the symbol and drag i...'),
#  Document(id=cc4356a8da176465f42f7b4b91a9f2764338a723af37ff0636bf77dbe669dc1e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Tables store tabular informa...'),
#  Document(id=4851e4bc0840fd6154e1f76b5d8339126e810bc8c61f5c389ef3e8e296632212, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  At some point, you may want ...'),
#  Document(id=1913f93db02ced66f3e13e58a46e27402770f6599b23a30f808cc66463305e1f, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The content of a table can b...'),
#  Document(id=2016f8773591ea25eaf1fe5209f784dc164a31dc0d2fdcfb784c45a74a6a84de, content: 'Tables:
#  ---
#  +-----+------------------+--------------------------------------------------------------...'),
#  Document(id=fbaf6948eaa92619bc18b5bfa7313ae850adb47bb41e2640b90a4a77be807da8, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  In another application, such...'),
#  Document(id=45d0c772835b6881d70f5df95e3376a3c3e486488af92197115f10ad30dcaa8e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  TheTableDefinitionsdialog bo...'),
#  Document(id=df64c874fd9b47f643f579d00ceb67fd07b44d848ee20ab1f95a2cadacda731b, content: 'Tables:
#  ---
#  +-----+----------------+----------------------------------------------------------------...'),
#  Document(id=9d3de492507cabd799e06fb0179b14643883f48b6fbdeceb11d0a2f121135e70, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  If you have edited an existi...'),
#  Document(id=bb9c3541f375c74975417a0eabb7e666ce80fde92baa229062da0fc4d559a6e3, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  You can define a geological ...'),
#  Document(id=cb5786394ca1af94a985df8966b0860b4c867a826b769b1d9af97f6e0e80f483, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Any track text, such as rema...'),
#  Document(id=fd15020c7aa8f7fd59940d388d8792d738e1d792659b74fa6f3c8886875191a6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  GEO  supports touch screen g...'),
#  Document(id=1e367f4ca6f22f5fb0c84e011f2cb50092cb3bca86c8fe24097835b0e74a7f3d, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The index converter calculat...'),
#  Document(id=97ab1ece378e3ac10263d19535e4e161e14d6761d32b0973c364d0fc02b090e6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  You can present the True Ver...'),
#  Document(id=dc5ef9c9af965472958e1b3aa0bda0f23c66afd35b6b993245313cde48c1dc4a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Add vertical chronological o...'),
#  Document(id=318955ce20dda97888b0877861e1611ca875ea7fcccf922415f72ec23bae3e85, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Hover the cursor over the ve...'),
#  Document(id=0c82dc4c49c299dbfe438d76e5577cdbd7c461f050288349b986bda0b1162ce6, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Right click on the track tex...'),
#  Document(id=aade072d46e23e1462b04d9ff9f8eb0f6a51db6b732c4f8691ac60d6c91f50ba, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Double click on the text you...'),
#  Document(id=2e3dc20c01c70d86825aa5f72bd71263290331a59be93ac2e71110de69e2da71, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Use the stratigraphy manager...'),
#  Document(id=22786390e9ef0dc73b2460cc1b6e60ca28bb6468ad97a9a42f260de013dad40e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The following information is...'),
#  Document(id=650d1396c4846ce2771345c411614d0a2b1013ee642609591d2a9ee714f49bff, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Vector Objects (symbols, mod...'),
#  Document(id=cd2c680d0d5f1d264e75e0d65eaf07628682117392e000dbfa39a17cde4867a3, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  On theGEOtab, selectClose.
#
#  ...'),
#  Document(id=f9dce3bd1bf38e66399d60cf116151b1293f845e2d0b0371396e25879b357dd9, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Files reside in directories ...'),
#  Document(id=7a56e0219d8af34e43adb0f3289a8377c6eb5dc180773bff47568072f21c9c6e, content: 'Tables:
#  ---
#  +-----+--------------------------------+---------------------+--------------------------...'),
#  Document(id=c4ea89c94b8f593d0595136af0aa93e45c76e0a5a15125880dcbc53e9bf03a6e, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Open the layout you wish to ...'),
#  Document(id=9177ba12cf5aa8fc999b5af0f4dff9cd8239eac372fd41f748a9bcb151c6bb99, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  If an ODF file, has a data r...'),
#  Document(id=24cd512a9227f1441ee30a7baa83a2af120192649e25978ddca7520195d4fa11, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  A template (ODT) can be crea...'),
#  Document(id=cfa418f59cd2fee891feff614360c1e8794984cf206418206c666b850055812b, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The ODF Update File or OUF, ...'),
#  Document(id=0b66715278ac65c1e8b5dc55b1e336a1624fca90c78263578a5ff232722cac9c, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  On theGEOtab selectOpen.Ther...'),
#  Document(id=ff94aa9446211f1c450ff1363abf15f61b19f7fb1168d32261f1fd11cac32012, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  On theGEOMenu, selectTemplat...'),
#  Document(id=16ec345721200eb74f240820dd1676d66e5d3573f52c0cc08e848d2fe4a50beb, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  The Output Database File or ...'),
#  Document(id=d8148331175c525563250c5af2907d966297563b9a260e1d1c6d700b9934a056, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  When an ODF file is saved in...'),
#  Document(id=c6636e8d6c7c694dfa1a4d7786c249e2de85ac31fa27a6864d4377dd3828524b, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  On theGEOmenu, selectTemplat...'),
#  Document(id=370406c99de0397c6b22c602ec6f6194a25c67b36f7668c09be8aed1e7da254a, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  Open the layout which contai...'),
#  Document(id=ea5e2781f0fc37a59eee192d06c2899d65a7814f0f9c9b19644185f55fd5c89b, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  A VEW file contains informat...'),
#  Document(id=6e50095a4265a6bfd7b63c5aabb1024819e0163064e7c1954f0d4c360f98df41, content: 'Tables:
#  ---
#
#  ---
#  Text:
#  ---
#  *Maximize screen to view table of contents*
#
#  ODF files may be shared with...')]

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"

# %%
import os

api_key = os.getenv("OPENAI_API_KEY")
if api_key:
    os.environ["OPENAI_API_KEY"] = api_key
    print(f"API key: {api_key}")
else:
    raise ValueError("API key not found. Set OPENAI_API_KEY as an environment variable.")
# Out:
# API key: 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

# %%
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.writers import DocumentWriter
from haystack.components.embedders import SentenceTransformersDocumentEmbedder

# %%
documents = _load_content()
# Out:
# Content:
# Tables:
# ---
# +-----+----------------------------------------------------------------+-----------+
# |   0 | Types                                                          | Limits    |
# +=====+================================================================+===========+
# |   1 | Curves                                                         |           |
# +-----+----------------------------------------------------------------+-----------+
# |   2 | Number of curves                                               | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |   3 | Size of curve units                                            | 24        |
# +-----+----------------------------------------------------------------+-----------+
# |   4 | Size of curve name                                             | 90        |
# +-----+----------------------------------------------------------------+-----------+
# |   5 | Number of data files to form one curve                         | None      |
# +-----+----------------------------------------------------------------+-----------+
# |   6 | Number of pen definitions                                      | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |   7 | Curve selection name                                           | 60        |
# +-----+----------------------------------------------------------------+-----------+
# |   8 | Curve to lithology name                                        | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |   9 | Curve to lithology lithology types                             | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  10 | Data points per curve                                          | Unlimited |
# +-----+----------------------------------------------------------------+-----------+
# |  11 | Computed curve parameters                                      | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  12 | Size of computed curve parameters name                         | 12        |
# +-----+----------------------------------------------------------------+-----------+
# |  13 | Computed curve expressions                                     | 300       |
# +-----+----------------------------------------------------------------+-----------+
# |  14 | Size of computed curve expressions name                        | 25        |
# +-----+----------------------------------------------------------------+-----------+
# |  15 | Size of computed curve parameter description                   | 150       |
# +-----+----------------------------------------------------------------+-----------+
# |  16 | Number of 'curves for surfaces' definitions                    | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  17 | Number of curve synonym-pairs                                  | 500       |
# +-----+----------------------------------------------------------------+-----------+
# |  18 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  19 | Tracks                                                         |           |
# +-----+----------------------------------------------------------------+-----------+
# |  20 | Number of tracks                                               | 200       |
# +-----+----------------------------------------------------------------+-----------+
# |  21 | Number of qualitative tracks                                   | 30        |
# +-----+----------------------------------------------------------------+-----------+
# |  22 | Size of track name                                             | 75        |
# +-----+----------------------------------------------------------------+-----------+
# |  23 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  24 | Curve Shading                                                  |           |
# +-----+----------------------------------------------------------------+-----------+
# |  25 | Number of curve shades per plot                                | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  26 | Number of zones per curve shade                                | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  27 | Curve shade name length                                        | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  28 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  29 | Data Files                                                     |           |
# +-----+----------------------------------------------------------------+-----------+
# |  30 | Number of data files                                           | Unlimited |
# +-----+----------------------------------------------------------------+-----------+
# |  31 | Columns per data file                                          | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |  32 | Size of file name (including the path names)                   | 255       |
# +-----+----------------------------------------------------------------+-----------+
# |  33 | Size of file ID                                                | 9         |
# +-----+----------------------------------------------------------------+-----------+
# |  34 | Number of file ID                                              | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  35 | Auto file load definition name                                 | 40        |
# +-----+----------------------------------------------------------------+-----------+
# |  36 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  37 | Mnemonics                                                      |           |
# +-----+----------------------------------------------------------------+-----------+
# |  38 | Number of mnemonics per file                                   | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  39 | Number of mnemonics per plot                                   | 600       |
# +-----+----------------------------------------------------------------+-----------+
# |  40 | Size of curve mnemonic                                         | 32        |
# +-----+----------------------------------------------------------------+-----------+
# |  41 | Size of file mnemonic value                                    | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  42 | Size of plot mnemonic value                                    | 1000      |
# +-----+----------------------------------------------------------------+-----------+
# |  43 | Size of mnemonic description                                   | 40        |
# +-----+----------------------------------------------------------------+-----------+
# |  44 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  45 | Free Format Text                                               |           |
# +-----+----------------------------------------------------------------+-----------+
# |  46 | Number of free format text blocks per plot                     | 4500      |
# +-----+----------------------------------------------------------------+-----------+
# |  47 | Number of characters per free format text block                | 250       |
# +-----+----------------------------------------------------------------+-----------+
# |  48 | Number of free format text's related to a symbol               | 6         |
# +-----+----------------------------------------------------------------+-----------+
# |  49 | Number of free format text tags                                | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  50 | Free format text tag size                                      | 31        |
# +-----+----------------------------------------------------------------+-----------+
# |  51 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  52 | Track Text                                                     |           |
# +-----+----------------------------------------------------------------+-----------+
# |  53 | Number of track text blocks per plot                           | 6000      |
# +-----+----------------------------------------------------------------+-----------+
# |  54 | Number of characters per track text block                      | 32000     |
# +-----+----------------------------------------------------------------+-----------+
# |  55 | Number of qualitative tracks                                   | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  56 | Number of graduations per qualitative track                    | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  57 | Qualitative track name length                                  | 32        |
# +-----+----------------------------------------------------------------+-----------+
# |  58 | Qualitative track abbreviation length                          | 8         |
# +-----+----------------------------------------------------------------+-----------+
# |  59 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  60 | Tables                                                         |           |
# +-----+----------------------------------------------------------------+-----------+
# |  61 | Number of tables                                               | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  62 | Number of rows in 'operations diary' type table                | 4320      |
# +-----+----------------------------------------------------------------+-----------+
# |  63 | Number of rows in 'normal' and 'operations remarks' type table | 32000     |
# +-----+----------------------------------------------------------------+-----------+
# |  64 | Number of fields in a row`                                     | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  65 | Columns per table                                              | 4320      |
# +-----+----------------------------------------------------------------+-----------+
# |  66 | Size of table name                                             | 29        |
# +-----+----------------------------------------------------------------+-----------+
# |  67 | Size of table ID                                               | 12        |
# +-----+----------------------------------------------------------------+-----------+
# |  68 | Size of table column heading                                   | 29        |
# +-----+----------------------------------------------------------------+-----------+
# |  69 | Size of postfix                                                | 20        |
# +-----+----------------------------------------------------------------+-----------+
# |  70 | Characters for all columns in table                            | 10000     |
# +-----+----------------------------------------------------------------+-----------+
# |  71 | Characters for an individual cell                              | 1999      |
# +-----+----------------------------------------------------------------+-----------+
# |  72 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  73 | Lithology (includes Structures)                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  74 | Number of lithology types                                      | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |  75 | Number of lithology sections per plot                          | 20000     |
# +-----+----------------------------------------------------------------+-----------+
# |  76 | %Litho track per plot                                          | 3         |
# +-----+----------------------------------------------------------------+-----------+
# |  77 | Number of lithology types per %Litho track                     | 10        |
# +-----+----------------------------------------------------------------+-----------+
# |  78 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  79 | Modifiers                                                      |           |
# +-----+----------------------------------------------------------------+-----------+
# |  80 | Number of modifier types                                       | 450       |
# +-----+----------------------------------------------------------------+-----------+
# |  81 | Number of modifiers per plot                                   | 20000     |
# +-----+----------------------------------------------------------------+-----------+
# |  82 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  83 | Symbols                                                        |           |
# +-----+----------------------------------------------------------------+-----------+
# |  84 | Number of symbol types                                         | 1000      |
# +-----+----------------------------------------------------------------+-----------+
# |  85 | Number of symbols per plot                                     | 10000     |
# +-----+----------------------------------------------------------------+-----------+
# |  86 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  87 | Lines                                                          |           |
# +-----+----------------------------------------------------------------+-----------+
# |  88 | Number of lines per plot                                       | 750       |
# +-----+----------------------------------------------------------------+-----------+
# |  89 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  90 | Headers and Trailers                                           |           |
# +-----+----------------------------------------------------------------+-----------+
# |  91 | Number of header & trailers specification files                | 100       |
# +-----+----------------------------------------------------------------+-----------+
# |  92 | Number of specifications to make a plot header                 | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  93 | Number of specifications to make a plot trailer                | 50        |
# +-----+----------------------------------------------------------------+-----------+
# |  94 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# |  95 | Tadpole                                                        |           |
# +-----+----------------------------------------------------------------+-----------+
# |  96 | Tadpole definitions                                            | 5         |
# +-----+----------------------------------------------------------------+-----------+
# |  97 | Tadpole definitions name                                       | 16        |
# +-----+----------------------------------------------------------------+-----------+
# |  98 | Minimum dip value                                              | 0         |
# +-----+----------------------------------------------------------------+-----------+
# |  99 | Maximum dip value                                              | 90        |
# +-----+----------------------------------------------------------------+-----------+
# | 100 | Minimum azimuth value                                          | 0         |
# +-----+----------------------------------------------------------------+-----------+
# | 101 | Maximum azimuth value                                          | 360       |
# +-----+----------------------------------------------------------------+-----------+
# | 102 | Maximum dip types                                              | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 103 | Maximum length of dip type name                                | 63        |
# +-----+----------------------------------------------------------------+-----------+
# | 104 | Maximum tadpole definition templates                           | 50        |
# +-----+----------------------------------------------------------------+-----------+
# | 105 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 106 | System/General                                                 |           |
# +-----+----------------------------------------------------------------+-----------+
# | 107 | Minimum zoom                                                   | 0.1       |
# +-----+----------------------------------------------------------------+-----------+
# | 108 | Maximum zoom                                                   | 10        |
# +-----+----------------------------------------------------------------+-----------+
# | 109 | Size of plot description                                       | 29        |
# +-----+----------------------------------------------------------------+-----------+
# | 110 | Number of CGM fonts for font mapping                           | 20        |
# +-----+----------------------------------------------------------------+-----------+
# | 111 | Size of CGM font name                                          | 30        |
# +-----+----------------------------------------------------------------+-----------+
# | 112 | Scale settings                                                 | 23        |
# +-----+----------------------------------------------------------------+-----------+
# | 113 | Password length                                                | 16        |
# +-----+----------------------------------------------------------------+-----------+
# | 114 | Size of image name                                             | 32        |
# +-----+----------------------------------------------------------------+-----------+
# | 115 | User ID's per plot                                             | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 116 | Vendor ID's per plot                                           | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 117 | Maximum layouts per ODF                                        | 19        |
# +-----+----------------------------------------------------------------+-----------+
# | 118 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 119 | VectDraw or Vector Object                                      |           |
# +-----+----------------------------------------------------------------+-----------+
# | 120 | Number of points per polygon in VOB                            | 20        |
# +-----+----------------------------------------------------------------+-----------+
# | 121 | Number of different fonts for VOB                              | 50        |
# +-----+----------------------------------------------------------------+-----------+
# | 122 | Size of text in VOB                                            | 300       |
# +-----+----------------------------------------------------------------+-----------+
# | 123 | Memory for all bitmaps and VOBs                                | 300 KB    |
# +-----+----------------------------------------------------------------+-----------+
# | 124 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 125 | Imaging Tools                                                  |           |
# +-----+----------------------------------------------------------------+-----------+
# | 126 | Maximum imaging tools                                          | 10        |
# +-----+----------------------------------------------------------------+-----------+
# | 127 | Maximum pads per tool                                          | 10        |
# +-----+----------------------------------------------------------------+-----------+
# | 128 | Maximum sensors per pad                                        | 64        |
# +-----+----------------------------------------------------------------+-----------+
# | 129 | Maximum name length                                            | 63        |
# +-----+----------------------------------------------------------------+-----------+
# | 130 | Maximum significant decimals                                   | 4         |
# +-----+----------------------------------------------------------------+-----------+
# | 131 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 132 | Zones                                                          |           |
# +-----+----------------------------------------------------------------+-----------+
# | 133 | Number of query definitions per zone type                      | 75        |
# +-----+----------------------------------------------------------------+-----------+
# | 134 |                                                                |           |
# +-----+----------------------------------------------------------------+-----------+
# | 135 | Correlation                                                    |           |
# +-----+----------------------------------------------------------------+-----------+
# | 136 | Correlation items                                              | 50        |
# +-----+----------------------------------------------------------------+-----------+
# ---
# Text:
# ---
# *Maximize screen to view table of contents*
#
# The following restrictions currently apply within each session of GEO, or instance ofODFfile.
#
# Once a limit is reached, the system may beep and/or display an error message for that object type.
#
# To check whether the following limits have been exceeded, click Statistics from the Help menu.
#
# The Statistics dialog box displays the number of modifiers, lithologies, symbols, texts and lines, which are being used in the currently-open ODF.
# ---
# List:
# ---
# []
# ---

# %%
# Use a set to track unique documents based on content and meta
unique_docs = {}
for doc in documents:
    doc_key = (doc.content.strip(), tuple(doc.meta.items()))  # Normalize content & meta
    if doc_key not in unique_docs:
        unique_docs[doc_key] = doc

# %%
documents = list(unique_docs.values())

# %%
document_store = InMemoryDocumentStore()

indexing_pipeline = Pipeline()
indexing_pipeline.add_component(
    instance=SentenceTransformersDocumentEmbedder(model="sentence-transformers/all-MiniLM-L6-v2"), name="doc_embedder"
)
indexing_pipeline.add_component(instance=DocumentWriter(document_store=document_store), name="doc_writer")

indexing_pipeline.connect("doc_embedder.documents", "doc_writer.documents")

indexing_pipeline.run({"doc_embedder": {"documents": documents}})
# Out:
# Batches:   0%|          | 0/9 [00:00<?, ?it/s]
# {'doc_writer': {'documents_written': 268}}

# %%
from haystack.components.embedders import SentenceTransformersTextEmbedder
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.builders import ChatPromptBuilder
from haystack.dataclasses import ChatMessage
from haystack.components.generators.chat import OpenAIChatGenerator

# %%
template = [
    ChatMessage.from_system(
        """
        You are an assistant designed to help users become more familiar with the GEO application.
        
        GEO is a PC-based well log authoring, analysis, and reporting system developed for 
        petroleum geologists, geoscientists, and engineers.
        
        Answer the user's questions accurately using retrieved information from the "Context" 
        section. This section contains help content written by software developers specifically 
        for the GEO application.
        
        Ensure that your response is concise and directly addresses the question, avoiding any 
        irrelevant information. The generated response should contain only the answer to the 
        user's question.
        
        Use the information from the section titled "---Feedback---" as guidelines for improving 
        your answers. Assess the validity and feasibility of the feedback before applying it to 
        refine future responses.

        Context:
        {% for document in documents %}
            {{ document.content }}
        {% endfor %}

        Question: {{ question }}
        Answer:
        """
    )
]

# %%
rag_pipe = Pipeline()
rag_pipe.add_component("embedder", SentenceTransformersTextEmbedder(model="sentence-transformers/all-MiniLM-L6-v2"))
rag_pipe.add_component("retriever", InMemoryEmbeddingRetriever(document_store=document_store))
rag_pipe.add_component("prompt_builder", ChatPromptBuilder(template=template))
rag_pipe.add_component("llm", OpenAIChatGenerator(model="gpt-4o-mini"))

# %%
rag_pipe.connect("embedder.embedding", "retriever.query_embedding")
rag_pipe.connect("retriever", "prompt_builder.documents")
rag_pipe.connect("prompt_builder.prompt", "llm.messages")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x0000015EA35A1190>
# 🚅 Components
#   - embedder: SentenceTransformersTextEmbedder
#   - retriever: InMemoryEmbeddingRetriever
#   - prompt_builder: ChatPromptBuilder
#   - llm: OpenAIChatGenerator
# 🛤️ Connections
#   - embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> llm.messages (List[ChatMessage])

# %%
questions = [
    "What's the maximum number of lithology types in a log?",
    "How many tracks can you define in one ODF?",
    "How many curve shades can I create?",
    "How many curves can I load in one go?",
    "What's the maximum number of headers I can display in my log?",
    "How many tables can I have in my log?",
    "What's the maximum number of characters in a single text entry?",
    "How many symbols can I have in the plot at any one time?",
    "How many scales can I define?",
    "What's the maximum number of data files I can load?"
]

# %%
predicted_responses = []
for query in questions:
    response = rag_pipe.run({"embedder": {"text": query}, "prompt_builder": {"question": query}})
    print(f"Question: {query}")
    predicted_responses.append(response['llm']['replies'][0]._content[0].text)
    print(f"Response: {response['llm']['replies'][0]._content[0].text}")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: What's the maximum number of lithology types in a log?
# Response: The maximum number of lithology types in a log is 450.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: How many tracks can you define in one ODF?
# Response: Up to 250 shadings can be applied in one ODF.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: How many curve shades can I create?
# Response: You can create up to 250 curve shades in one ODF.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: How many curves can I load in one go?
# Response: You can load an unlimited number of data files in one go.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: What's the maximum number of headers I can display in my log?
# Response: The context does not specify a maximum number of headers that can be displayed in a log, so that information is not available.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: How many tables can I have in my log?
# Response: The information regarding the maximum number of tables that can be included in a log is not specified in the provided content. Please refer to the GEO application documentation or contact support for clarification.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: What's the maximum number of characters in a single text entry?
# Response: The maximum number of characters for a curve mnemonic or unit must not exceed thirty-two characters.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: How many symbols can I have in the plot at any one time?
# Response: The maximum number of symbols per plot is 10,000.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: How many scales can I define?
# Response: You can define multiple scales for a curve in a plot.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Question: What's the maximum number of data files I can load?
# Response: The GEO application does not specify a maximum number of data files that can be loaded; it can load multiple ASCII files as long as they meet the formatting requirements.

# %%
sample_responses = [
    450, 
    200, 
    250, 
    450, 
    50, 
    100, 
    "250 / 32000 (varies per text type)", 
    10000, 
    23, 
    "unlimited"
]

print(f"sample response: {sample_responses}")
# Out:
# sample response: [450, 200, 250, 450, 50, 100, '250 / 32000 (varies per text type)', 10000, 23, 'unlimited']

# %%
print(f"predicted response: {predicted_responses}")
# Out:
# predicted response: ['The maximum number of lithology types in a log is 450.', 'Up to 250 shadings can be applied in one ODF.', 'You can create up to 250 curve shades in one ODF.', 'You can load an unlimited number of data files in one go.', 'The context does not specify a maximum number of headers that can be displayed in a log, so that information is not available.', 'The information regarding the maximum number of tables that can be included in a log is not specified in the provided content. Please refer to the GEO application documentation or contact support for clarification.', 'The maximum number of characters for a curve mnemonic or unit must not exceed thirty-two characters.', 'The maximum number of symbols per plot is 10,000.', 'You can define multiple scales for a curve in a plot.', 'The GEO application does not specify a maximum number of data files that can be loaded; it can load multiple ASCII files as long as they meet the formatting requirements.']

# %%
comparison_df = pd.DataFrame({
    "Expected Response": sample_responses,
    "Predicted Response": predicted_responses
})

# %%
import ace_tools_open as tools

# %%
tools.display_dataframe_to_user(name="Sample Question Results DataFrame", dataframe=comparison_df)
# Out:
# Sample Question Results DataFrame
# <table id="itables_828f8c9c_0041_467a_82dc_9fb59ea70baf" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Expected Response</th>
#       <th>Predicted Response</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.4 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_828f8c9c_0041_467a_82dc_9fb59ea70baf:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["450", "The maximum number of lithology types in a log is 450."], ["200", "Up to 250 shadings can be applied in one ODF."], ["250", "You can create up to 250 curve shades in one ODF."], ["450", "You can load an unlimited number of data files in one go."], ["50", "The context does not specify a maximum number of headers that can be displayed in a log, so that information is not available."], ["100", "The information regarding the maximum number of tables that can be included in a log is not specified in the provided content. Please refer to the GEO application documentation or contact support for clarification."], ["250 / 32000 (varies per text type)", "The maximum number of characters for a curve mnemonic or unit must not exceed thirty-two characters."], ["10000", "The maximum number of symbols per plot is 10,000."], ["23", "You can define multiple scales for a curve in a plot."], ["unlimited", "The GEO application does not specify a maximum number of data files that can be loaded; it can load multiple ASCII files as long as they meet the formatting requirements."]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
